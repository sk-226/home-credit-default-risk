# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
INPUT_DIR = "../data/input/"

df = pd.read_csv(INPUT_DIR + "train.csv")
test = pd.read_csv(INPUT_DIR + "test.csv")

# %%
col = ['OBS_30_CNT_SOCIAL_CIRCLE', 'DEF_30_CNT_SOCIAL_CIRCLE', 
        'OBS_60_CNT_SOCIAL_CIRCLE','DEF_60_CNT_SOCIAL_CIRCLE']

df[col].describe()
# Out:
#        OBS_30_CNT_SOCIAL_CIRCLE  DEF_30_CNT_SOCIAL_CIRCLE  \
# count             170642.000000             170642.000000
# mean                   1.423137                  0.143915
# std                    2.323733                  0.443579
# min                    0.000000                  0.000000
# 25%                    0.000000                  0.000000
# 50%                    0.000000                  0.000000
# 75%                    2.000000                  0.000000
# max                   47.000000                  8.000000
#
#        OBS_60_CNT_SOCIAL_CIRCLE  DEF_60_CNT_SOCIAL_CIRCLE
# count             170642.000000             170642.000000
# mean                   1.406406                  0.100438
# std                    2.303540                  0.360037
# min                    0.000000                  0.000000
# 25%                    0.000000                  0.000000
# 50%                    0.000000                  0.000000
# ...

# %%
sns.violinplot(x='TARGET', y='OBS_30_CNT_SOCIAL_CIRCLE', data=df)
# Out:
# <Axes: xlabel='TARGET', ylabel='OBS_30_CNT_SOCIAL_CIRCLE'>

# %%
sns.violinplot(x='TARGET', y='DEF_30_CNT_SOCIAL_CIRCLE', data=df)
# Out:
# <Axes: xlabel='TARGET', ylabel='DEF_30_CNT_SOCIAL_CIRCLE'>

# %%
sns.violinplot(x='TARGET', y='OBS_60_CNT_SOCIAL_CIRCLE', data=df)
# Out:
# <Axes: xlabel='TARGET', ylabel='OBS_60_CNT_SOCIAL_CIRCLE'>

# %%
sns.violinplot(x='TARGET', y='DEF_60_CNT_SOCIAL_CIRCLE', data=df)
# Out:
# <Axes: xlabel='TARGET', ylabel='DEF_60_CNT_SOCIAL_CIRCLE'>
