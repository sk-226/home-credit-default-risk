# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
INPUT_DIR = "../data/input/"

df = pd.read_csv(INPUT_DIR + "train.csv")
test = pd.read_csv(INPUT_DIR + "test.csv")

# %%
df['EXT_SOURCE_1'].describe()
# Out:
# count    52274.000000
# mean         0.501692
# std          0.210950
# min          0.017095
# 25%          0.333353
# 50%          0.505858
# 75%          0.674595
# max          0.947649
# Name: EXT_SOURCE_1, dtype: float64

# %%
df['EXT_SOURCE_2'].describe()
# Out:
# count    1.708330e+05
# mean     5.145083e-01
# std      1.912729e-01
# min      8.173617e-08
# 25%      3.920925e-01
# 50%      5.662998e-01
# 75%      6.641587e-01
# max      8.549997e-01
# Name: EXT_SOURCE_2, dtype: float64

# %%
df['EXT_SOURCE_3'].describe()
# Out:
# count    116616.000000
# mean          0.511177
# std           0.194778
# min           0.000527
# 25%           0.370650
# 50%           0.537070
# 75%           0.669057
# max           0.896010
# Name: EXT_SOURCE_3, dtype: float64

# %%
sns.violinplot(df["EXT_SOURCE_1"])
# Out:
# <Axes: >

# %%
sns.violinplot(df["EXT_SOURCE_2"])
# Out:
# <Axes: >

# %%
sns.violinplot(df["EXT_SOURCE_3"])
# Out:
# <Axes: >

# %%
df["EXT_SOURCE_3"].describe()
# Out:
# count    116616.000000
# mean          0.511177
# std           0.194778
# min           0.000527
# 25%           0.370650
# 50%           0.537070
# 75%           0.669057
# max           0.896010
# Name: EXT_SOURCE_3, dtype: float64
